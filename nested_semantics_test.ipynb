# %% [markdown]
# # Option 1 example output

# %%
import pandas as pd
import pm4py

from pm4py.objects.dcr.extended.obj import ExtendedDcrGraph
graph = ExtendedDcrGraph()
# events = [ "A", "B", "C", "D", "E", "F"]
# groups = ["N1", "N2", "N3"]
events = [
    "A", "B", "C", "D", "E", "F",  "N1", "N2", "N3"
]


for event in events:
    graph.events.add(event)
    graph.labels.add(event)
    graph.label_map[event] = event
    graph.marking.included.add(event)



#graph.nestedgroups["N1"] =  {"B", "N2"} 
#graph.nestedgroups["N2"] =  {"C", "D"} 
#graph.nestedgroups["N3"] =  {"E", "F"} 

graph.superActivities = {"N1" : {"B", "N2"}, "N2" : {"C", "D"}, "N3" : {"E", "F"}}

'''
for group, events in graph.nestedgroups.items():
    for e in events:
        graph.nestedgroups_map[e] = group
'''

# No corrosponding codeblock


graph.marking.included.remove("B")
graph.marking.pending.add("D")

# graph.conditions["N1"] = {"A"}
# graph.conditions["N3"] = {"N1"}
graph.conditions = {"N1" : {"A"}, "N3" : {"N1"}}

# graph.responses["N2"] = {"N3"}
graph.responses = {"N2" : {"N3"}}

# graph.includes["N3"] = {"B"}
graph.includes = {"N3" : {"B"}}

# graph.excludes["C"] = {"N2"}
graph.excludes = {"C" : {"N2"}}

# %%
import pandas as pd
from io import StringIO
import pm4py
from pm4py.objects.dcr.extended.semantics import ExtendedSemantics    # Should be HierarchicalDcrSemantics instead!

semantics = ExtendedSemantics()

errors = 0

expected_enabled = ["A"] # As seem in the simulation
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
if semantics.is_accepting(graph):
        errors+=1 
        raise Exception("Graph should NOT be accepting")        


semantics.execute(graph, "A")
expected_enabled = ["A", "C", "D"]
print("1th execution (Event A)")
print("Expected enabled", expected_enabled)
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                print("event", e)
                errors+=1 
                raise Exception("Event should NOT be enabled")
if semantics.is_accepting(graph):
        errors+=1 
        raise Exception("Graph should NOT be accepting")         


semantics.execute(graph, "C")
expected_enabled = ["A", "E", "F"]
print("2nd execution (Event C)")
print("Expected enabled", expected_enabled)
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 #raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 #raise Exception("Event should NOT be enabled")
if semantics.is_accepting(graph):
        errors+=1 #raise Exception("Graph should NOT be accepting")                


semantics.execute(graph, "E")
expected_enabled = ["A", "B"]
print("3rd execution (Event E)")
print("Expected enabled", expected_enabled)
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                print("event", e)
                errors+=1 
                raise Exception("Event should NOT be enabled")
if semantics.is_accepting(graph):
        errors+=1 
        raise Exception("Graph should NOT be accepting")                


semantics.execute(graph, "B")
expected_enabled = ["A", "B", "E", "F"]
print("4th execution (Event B)")
print("Expected enabled", expected_enabled)
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
        
if semantics.is_accepting(graph):
        errors+=1 
        raise Exception("Graph should NOT be accepting")    
            
semantics.execute(graph, "F")
expected_enabled = ["A", "B", "E", "F"]
print("5th execution (Event F)")
print("Expected enabled", expected_enabled)
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
if not semantics.is_accepting(graph):
        errors+=1
        raise Exception("Graph should not be accepting")                

if errors == 0:
      print("\nThe implementation passes all tests")
else:
      print("\nFound", errors)
# Out:
# 1th execution (Event A)
# Expected enabled ['A', 'C', 'D']
# 2nd execution (Event C)
# Expected enabled ['A', 'E', 'F']
# 3rd execution (Event E)
# Expected enabled ['A', 'B']
# 4th execution (Event B)
# Expected enabled ['A', 'B', 'E', 'F']
# 5th execution (Event F)
# Expected enabled ['A', 'B', 'E', 'F']
#
# The implementation passes all tests

# %%
import pandas as pd
import pm4py

from pm4py.objects.dcr.extended.obj import ExtendedDcrGraph
graph = ExtendedDcrGraph()

events = [
    "A", "B", "C", "D", "E", "F",  "N1", "N2", "N3"
]


for event in events:
    graph.events.add(event)
    graph.labels.add(event)
    graph.label_map[event] = event
    graph.marking.included.add(event)



graph.superActivities = {"N1": {'A', 'B'}, 'N2' : {"D", "C"}, 'N3' : {'E', 'F', 'N2'}}

graph.marking.included.remove("A")
graph.marking.included.remove("B")


graph.includes = {"C": {"N1"}}

graph.conditions = {"B": {"D"}}

graph.excludes = {"B" : {"N1"}}

# %%
import pandas as pd
from io import StringIO
import pm4py
from pm4py.objects.dcr.extended.semantics import ExtendedSemantics    # Should be HierarchicalDcrSemantics instead!

semantics = ExtendedSemantics()

errors = 0

expected_enabled = ["C", "D", "E", "F"]
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
if not semantics.is_accepting(graph):
        errors+=1
        raise Exception("Graph should not be accepting") 

print("Exeucting C")        
semantics.execute(graph, "C")
expected_enabled = ["A", "C", "D", "E", "F"]
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
if not semantics.is_accepting(graph):
        errors+=1
        raise Exception("Graph should not be accepting") 


print("Exeucting D")        
semantics.execute(graph, "D")
expected_enabled = ["A", "B", "C", "D", "E", "F"]
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
if not semantics.is_accepting(graph):
        errors+=1
        raise Exception("Graph should not be accepting") 


print("Exeucting B")        
semantics.execute(graph, "B")
expected_enabled = ["C", "D", "E", "F"]
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
if not semantics.is_accepting(graph):
        errors+=1
        raise Exception("Graph should not be accepting") 


if errors == 0:
      print("\nThe implementation passes all tests")
else:
      print("\nFound", errors)
# Out:
# Exeucting C
# Exeucting D
# Exeucting B
#
# The implementation passes all tests

# %%
import pandas as pd
import pm4py

from pm4py.objects.dcr.extended.obj import ExtendedDcrGraph
graph = ExtendedDcrGraph()
# events = [ "A", "B", "C", "D", "E", "F"]
# groups = ["N1", "N2", "N3"]
events = [
    "A", "B", "N1"
]


for event in events:
    graph.events.add(event)
    graph.labels.add(event)
    graph.label_map[event] = event
    graph.marking.included.add(event)


graph.superActivities = {"N1": {'A'}}
graph.marking.included.remove("N1")
graph.includes = {"B": {"N1"}}

# %%
semantics = ExtendedSemantics()

errors = 0

semantics.execute(graph, "B")
expected_enabled = ["A", "B"]
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")
if not semantics.is_accepting(graph):
        errors+=1
        raise Exception("Graph should not be accepting") 

if errors == 0:
      print("\nThe implementation passes all tests")
else:
      print("\nFound", errors)
# Out:
# The implementation passes all tests

# %%
import pandas as pd
import pm4py

from pm4py.objects.dcr.extended.obj import ExtendedDcrGraph
graph = ExtendedDcrGraph()

events = [
    "A", "B", "N1"
]


for event in events:
    graph.events.add(event)
    graph.labels.add(event)
    graph.label_map[event] = event
    graph.marking.included.add(event)


graph.superActivities = {"N1": {'A'}}
graph.marking.pending.add("N1")

graph.milestones = {"B": {"N1"}}

# %%
semantics = ExtendedSemantics()

errors = 0

expected_enabled = ["A"]
for e in events:
    if e in expected_enabled:
            if not semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should be enabled")
    if not (e in expected_enabled):
        if semantics.is_enabled(e, graph):
                errors+=1 
                raise Exception("Event should NOT be enabled")

if semantics.is_accepting(graph):
        errors+=1
        raise Exception("Graph should not be accepting") 

if errors == 0:
      print("\nThe implementation passes all tests")
else:
      print("\nFound", errors)
# Out:
# The implementation passes all tests

# %%
import pandas as pd
import pm4py

from pm4py.objects.dcr.extended.obj import ExtendedDcrGraph
graph = ExtendedDcrGraph()

events = [
    "A", "B", "N1", "C"
]


for event in events:
    graph.events.add(event)
    graph.labels.add(event)
    graph.label_map[event] = event
    graph.marking.included.add(event)


graph.superActivities = {"N1": {'A'}}
graph.marking.pending.add("N1")
graph.marking.included.remove("C")
graph.milestones = {"B": {"N1"}}

# %%
semantics = ExtendedSemantics()

errors = 0
#print(semantics.enabled(graph))
semantics.execute(graph, "B")
if graph.marking.executed.intersection(set("B")):
    print("B should not be allowed to execute")
    errors+=1
semantics.execute(graph, "C")
if graph.marking.executed.intersection(set("C")):
    print("Event C is correctly not enabled")
    errors+=1
    
if errors == 0:
      print("\nThe implementation passes all tests")
else:
      print("\nFound", errors)
# Out:
# The implementation passes all tests

# %%
import pandas as pd
import pm4py

from pm4py.objects.dcr.extended.obj import ExtendedDcrGraph
from pm4py.objects.dcr.semantics_old import DcrSemanticsOld 
graph = ExtendedDcrGraph()
semantics = DcrSemanticsOld()

events = [
    "A", "B", "C", "D"
]


for event in events:
    graph.events.add(event)
    graph.labels.add(event)
    graph.label_map[event] = event
    graph.marking.included.add(event)



graph.condition = {"B": {"A"}}
graph.includes = {"C" : {"A"}}
graph.excludes = {"D" : {"A"}}

# This disables A
semantics.execute(graph, "D")

semantics.execute(graph, "A")
if set("A").intersection(graph.marking.executed):
    print("A is not enabled, hence should not be in executed set")

#This should make A enabled, hence B should not be allowed to run
semantics.execute(graph, "C")
if set("B").intersection(semantics.enabled(graph)) and semantics.is_enabled("A", graph):
    print("B should not be enabled, as A is enabled, and the condition is not yet met")
# Out:
# A is not enabled, hence should not be in executed set
# B should not be enabled, as A is enabled, and the condition is not yet met
